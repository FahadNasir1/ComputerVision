# %% [markdown]
# <a href="https://colab.research.google.com/github/FahadNasir1/ComputerVision/blob/main/L7_Smoothing_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 #opencv itself
import numpy as np # matrix manipulations
# %matplotlib inline
from matplotlib import pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (2,2)

# %%
img=cv2.imread('box2.JPG')

# %%
kernel=np.ones((5,5),np.float32)/25
dst=cv2.filter2D(img,-1,kernel)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-eb72240e1d3f> in <cell line: 2>()
#       1 kernel=np.ones((5,5),np.float32)/25
# ----> 2 dst=cv2.filter2D(img,-1,kernel)
#       3 plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/filter.dispatch.cpp:1530: error: (-215:Assertion failed) !_src.empty() in function 'filter2D'

# %%
dst = cv2.blur(img,(5,5))
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-0e6cdb353c66> in <cell line: 1>()
# ----> 1 dst = cv2.blur(img,(5,5))
#       2 plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/box_filter.dispatch.cpp:446: error: (-215:Assertion failed) !_src.empty() in function 'boxFilter'

# %%
dst = cv2.GaussianBlur(img,(5,5),0)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))

# %%
dst = cv2.medianBlur(img,5)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
