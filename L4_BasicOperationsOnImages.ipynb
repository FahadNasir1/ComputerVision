# %% [markdown]
# <a href="https://colab.research.google.com/github/FahadNasir1/ComputerVision/blob/main/L4_BasicOperationsOnImages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# These imports let you use opencvimport cv2 #opencv itself
import numpy as np # matrix manipulations

#the following are to do with this interactive notebook code
# %matplotlib inline
from matplotlib import pyplot as plt # this lets you draw inline pictures in the notebooks
import pylab # this allows you to control figure size
import cv2

# %%
img1="family.jpg";
img = cv2.imread(img1, cv2.IMREAD_UNCHANGED)

print('Original Dimensions : ',img.shape)

scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (420, 614)

# resize image
img1 = cv2.resize(img, dim)
# Out:
# Original Dimensions :  (700, 1024, 3)

# %%
img2="box2.JPG";
img = cv2.imread(img2, cv2.IMREAD_UNCHANGED)

print('Original Dimensions : ',img.shape)

scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (420, 614)

# resize image
img2 = cv2.resize(img, dim)
# Out:
# Original Dimensions :  (330, 356, 3)

# %%
dst = cv2.addWeighted(img1,0.7,img2,0.3,0)
cv2.imwrite("pic.jpg",dst)
# Out:
# True

# %%
d=cv2.add(img1,img2)
cv2.imwrite("pic2.jpg",d)
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(d, cv2.COLOR_BGR2RGB))

# %%
d=cv2.subtract(img1,img2)
plt.imshow(cv2.cvtColor(d, cv2.COLOR_BGR2RGB))

# %%
d=cv2.divide(img1,img2)
plt.imshow(cv2.cvtColor(d, cv2.COLOR_BGR2RGB))

# %%
d=cv2.multiply(img1,img2)
plt.imshow(cv2.cvtColor(d, cv2.COLOR_BGR2RGB))
