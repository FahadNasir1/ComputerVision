# %% [markdown]
# <a href="https://colab.research.google.com/github/FahadNasir1/ComputerVision/blob/main/L6_Arithmetic_Operations_On_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 #opencv itself
import numpy as np # matrix manipulations
# %matplotlib inline
from matplotlib import pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (2,2)

# %%
img1="family.jpg";
img = cv2.imread(img1, cv2.IMREAD_UNCHANGED)

print('Original Dimensions : ',img.shape)

scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (420, 614)

# resize image
img1 = cv2.resize(img, dim)
# Out:
# Original Dimensions :  (700, 1024, 3)

# %%
img2="box2.JPG";
img = cv2.imread(img2, cv2.IMREAD_UNCHANGED)

print('Original Dimensions : ',img.shape)

scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (420, 614)

# resize image
img2 = cv2.resize(img, dim)
# Out:
# Original Dimensions :  (330, 356, 3)

# %%
dst = cv2.addWeighted(img1,0.7,img2,0.3,0)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
